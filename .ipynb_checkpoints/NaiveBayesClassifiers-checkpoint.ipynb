# %% [markdown]
# # Importing Libraries

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Loading Dataset

# %%
data=pd.read_csv('log2.csv')
data
# Out:
#        Source Port  Destination Port  NAT Source Port  NAT Destination Port  \
# 0            57222                53            54587                    53
# 1            56258              3389            56258                  3389
# 2             6881             50321            43265                 50321
# 3            50553              3389            50553                  3389
# 4            50002               443            45848                   443
# ...            ...               ...              ...                   ...
# 65527        63691                80            13237                    80
# 65528        50964                80            13485                    80
# 65529        54871               445                0                     0
# 65530        54870               445                0                     0
# 65531        54867               445                0                     0
#
#       Action    Bytes  Bytes Sent  Bytes Received  Packets  \
# 0      allow      177          94              83        2
# 1      allow     4768        1600            3168       19
# 2      allow      238         118             120        2
# 3      allow     3327        1438            1889       15
# 4      allow    25358        6778           18580       31
# ...      ...      ...         ...             ...      ...
# 65527  allow      314         192             122        6
# 65528  allow  4680740       67312         4613428     4675
# 65529   drop       70          70               0        1
# 65530   drop       70          70               0        1
# 65531   drop       70          70               0        1
#
#        Elapsed Time (sec)  pkts_sent  pkts_received
# 0                      30          1              1
# 1                      17         10              9
# 2                    1199          1              1
# 3                      17          8              7
# 4                      16         13             18
# ...                   ...        ...            ...
# 65527                  15          4              2
# 65528                  77        985           3690
# 65529                   0          1              0
# 65530                   0          1              0
# 65531                   0          1              0
#
# [65532 rows x 12 columns]

# %% [markdown]
# # Data Analyzing

# %%
data.shape
# Out:
# (65532, 12)

# %%
data.isnull().sum()
# Out:
# Source Port             0
# Destination Port        0
# NAT Source Port         0
# NAT Destination Port    0
# Action                  0
# Bytes                   0
# Bytes Sent              0
# Bytes Received          0
# Packets                 0
# Elapsed Time (sec)      0
# pkts_sent               0
# pkts_received           0
# dtype: int64

# %%
data.dtypes
# Out:
# Source Port              int64
# Destination Port         int64
# NAT Source Port          int64
# NAT Destination Port     int64
# Action                  object
# Bytes                    int64
# Bytes Sent               int64
# Bytes Received           int64
# Packets                  int64
# Elapsed Time (sec)       int64
# pkts_sent                int64
# pkts_received            int64
# dtype: object

# %%
data['Action'].value_counts()
# Out:
# allow         37640
# deny          14987
# drop          12851
# reset-both       54
# Name: Action, dtype: int64

# %% [markdown]
# # Splitting Dataset

# %%
x=data.drop('Action',axis=1)
x
# Out:
#        Source Port  Destination Port  NAT Source Port  NAT Destination Port  \
# 0            57222                53            54587                    53
# 1            56258              3389            56258                  3389
# 2             6881             50321            43265                 50321
# 3            50553              3389            50553                  3389
# 4            50002               443            45848                   443
# ...            ...               ...              ...                   ...
# 65527        63691                80            13237                    80
# 65528        50964                80            13485                    80
# 65529        54871               445                0                     0
# 65530        54870               445                0                     0
# 65531        54867               445                0                     0
#
#          Bytes  Bytes Sent  Bytes Received  Packets  Elapsed Time (sec)  \
# 0          177          94              83        2                  30
# 1         4768        1600            3168       19                  17
# 2          238         118             120        2                1199
# 3         3327        1438            1889       15                  17
# 4        25358        6778           18580       31                  16
# ...        ...         ...             ...      ...                 ...
# 65527      314         192             122        6                  15
# 65528  4680740       67312         4613428     4675                  77
# 65529       70          70               0        1                   0
# 65530       70          70               0        1                   0
# 65531       70          70               0        1                   0
#
#        pkts_sent  pkts_received
# 0              1              1
# 1             10              9
# 2              1              1
# 3              8              7
# 4             13             18
# ...          ...            ...
# 65527          4              2
# 65528        985           3690
# 65529          1              0
# 65530          1              0
# 65531          1              0
#
# [65532 rows x 11 columns]

# %%
y=pd.DataFrame(data['Action'])
y
# Out:
#       Action
# 0      allow
# 1      allow
# 2      allow
# 3      allow
# 4      allow
# ...      ...
# 65527  allow
# 65528  allow
# 65529   drop
# 65530   drop
# 65531   drop
#
# [65532 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split 
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.4, random_state=1)

# %% [markdown]
# # training the model on training set

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn import metrics
gnb = GaussianNB() 
gnb.fit(x_train, y_train.values.ravel())
# Out:
# GaussianNB(priors=None, var_smoothing=1e-09)

# %% [markdown]
# # making predictions on the testing set

# %%
y_pred = gnb.predict(x_test)

# %% [markdown]
# # Accuracy

# %%
print("Gaussian Naive Bayes model accuracy(in %):", metrics.accuracy_score(y_test, y_pred)*100)
# Out:
# Gaussian Naive Bayes model accuracy(in %): 72.55560218212337

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#        allow       1.00      0.53      0.69     15026
#         deny       0.90      0.98      0.94      6014
#         drop       0.96      1.00      0.98      5155
#   reset-both       0.00      0.33      0.00        18
#
#     accuracy                           0.73     26213
#    macro avg       0.72      0.71      0.65     26213
# weighted avg       0.97      0.73      0.81     26213
